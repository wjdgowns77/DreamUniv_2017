# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# #1장. 파이썬 소개

# %% [markdown]
# ##파이썬과 인사하기

# %%
print("hello world")
# Out:
# hello world

# %%
#주석
print("programming 세계에 오신 것을 환영합니다")
# Out:
# programming 세계에 오신 것을 환영합니다

# %% [raw]
# ## 계산하기

# %%
print("2+3") #이것은 더하기
print("2-3") #이것은 빼기
print("2*3") #이것은 곱하기
print("2/3") #이것은 나누기
# Out:
# 2+3
# 2-3
# 2*3
# 2/3

# %%
print("56546465465465465*5465465145615641654")
# Out:
# 56546465465465465*5465465145615641654

# %%
2*128
# Out:
# 256

# %%
2**128
# Out:
# 340282366920938463463374607431768211456

# %%
print(3.141592*10.0*10.0)
# Out:
# 314.1592

# %%
print((1/100)*1234)
# Out:
# 12.34

# %% [markdown]
# ##문자열 출력하기

# %%
print("강아지"+"고양이")
# Out:
# 강아지고양이

# %%
print("강아지","고양이")
# Out:
# 강아지 고양이

# %%
print("반가워"*10600)
# Out:
# 반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가워반가
# ...

# %%
print("100"+"200")
# Out:
# 100200

# %%
print(100+200)
# Out:
# 300

# %% [markdown]
# ## 에러를 무서워 하지말자

# %%
pront("helloworld")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-87a61b6bc518> in <module>()
# ----> 1 pront("helloworld")
#
# NameError: name 'pront' is not defined

# %%
3-+---2*5645526845-*545
# Out:
#   File "<ipython-input-19-e1ccdc8565e2>", line 1
#     3-+---2*5645526845-*545
#                        ^
# SyntaxError: invalid syntax

# %%
print("hello")
# Out:
# hello
